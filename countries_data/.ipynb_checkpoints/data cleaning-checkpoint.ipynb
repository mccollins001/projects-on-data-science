# %% [markdown]
# # Data cleaning with pandas

# %% [markdown]
# ## Import necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read data from CSV file

# %%
world = pd.read_csv('countries.csv',sep = ';')
world = world.iloc[1:,:]

# %% [markdown]
# ## First and last five Rows

# %%
world.head()
# Out:
#           Country Area(sq km) Birth rate(births/1000 population)  \
# 1     Afghanistan      647500                              47.02
# 2        Akrotiri         123                                NaN
# 3         Albania       28748                              15.08
# 4         Algeria     2381740                              17.13
# 5  American Samoa         199                              23.13
#
#   Current account balance Death rate(deaths/1000 population) Debt - external  \
# 1                     NaN                              20.75      8000000000
# 2                     NaN                                NaN             NaN
# 3              -504000000                               5.12      1410000000
# 4             11900000000                               4.60     21900000000
# 5                     NaN                               3.33             NaN
#
#   Electricity - consumption(kWh) Electricity - production(kWh)      Exports  \
# ...

# %%
world.tail()
# Out:
#             Country Area(sq km) Birth rate(births/1000 population)  \
# 259       West Bank        5860                              32.37
# 260  Western Sahara      266000                                NaN
# 261           Yemen      527970                              43.07
# 262          Zambia      752614                              41.38
# 263        Zimbabwe      390580                              29.74
#
#     Current account balance Death rate(deaths/1000 population)  \
# 259                     NaN                               3.99
# 260                     NaN                                NaN
# 261               369900000                               8.53
# 262              -181400000                              20.23
# 263              -230300000                              24.66
#
#     Debt - external Electricity - consumption(kWh)  \
# 259       108000000                            NaN
# 260             NaN                       83700000
# ...

# %% [markdown]
# ## Total number of rows and columns

# %%
world.shape
# Out:
# (263, 45)

# %% [markdown]
# ## checking for null values

# %%
world.isnull().head()
# Out:
#    Country  Area(sq km)  Birth rate(births/1000 population)  \
# 1    False        False                               False
# 2    False        False                                True
# 3    False        False                               False
# 4    False        False                               False
# 5    False        False                               False
#
#    Current account balance  Death rate(deaths/1000 population)  \
# 1                     True                               False
# 2                     True                                True
# 3                    False                               False
# 4                    False                               False
# 5                     True                               False
#
#    Debt - external  Electricity - consumption(kWh)  \
# 1            False                           False
# 2             True                            True
# 3            False                           False
# ...

# %% [markdown]
# ## sum of null values for first 5 columns

# %%
world.isnull().sum()
# Out:
# Country                                             0
# Area(sq km)                                         0
# Birth rate(births/1000 population)                 38
# Current account balance                           114
# Death rate(deaths/1000 population)                 38
# Debt - external                                    62
# Electricity - consumption(kWh)                     48
# Electricity - production(kWh)                      50
# Exports                                            39
# GDP                                                33
# GDP - per capita                                   33
# GDP - real growth rate(%)                          51
# HIV/AIDS - adult prevalence rate(%)                95
# HIV/AIDS - deaths                                 115
# HIV/AIDS - people living with HIV/AIDS             99
# Highways(km)                                       33
# Imports                                            39
# ...

# %% [markdown]
# ## Total number of null values

# %%
world.isnull().sum().sum()
# Out:
# 3656

# %% [markdown]
# ## data cleaning by back-filling the null data

# %%
world = world.fillna(method = 'bfill')

# %% [markdown]
# ## Filling null values by padding

# %%
world = world.fillna(method = 'pad')

# %% [markdown]
# ## checking for null values

# %%
world.isnull().sum().sum()
# Out:
# 0
